# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
data=datasets.load_boston()
data1=pd.DataFrame(data.data)
Y=data.target

# %%
data1.columns=['x1','x2','x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13']

# %%
boston=datasets.load_boston()
X=boston.data
Y=boston.target
import pandas as pd
df = pd.DataFrame(X)
print (boston.feature_names)
df.columns=boston.feature_names
df.describe()
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.593761   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.596783   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.647423   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# ...

# %%
from sklearn import model_selection as ms
from sklearn.linear_model import LinearRegression as LR

# %%
#we are going to add new features to X

x=len(boston.feature_names)
for i in range(x):
    for j in range(i,x):
        f1=df.columns[i]
        f2=df.columns[j]
        f_name=f1+'_'+f2
        print f_name
        df[f_name]=df[f1]*df[f2]
# Out:
# CRIM_CRIM
# CRIM_ZN
# CRIM_INDUS
# CRIM_CHAS
# CRIM_NOX
# CRIM_RM
# CRIM_AGE
# CRIM_DIS
# CRIM_RAD
# CRIM_TAX
# CRIM_PTRATIO
# CRIM_B
# CRIM_LSTAT
# ZN_ZN
# ZN_INDUS
# ZN_CHAS
# ZN_NOX
# ZN_RM
# ZN_AGE
# ZN_DIS
# ZN_RAD
# ZN_TAX
# ZN_PTRATIO
# ZN_B
# ZN_LSTAT
# INDUS_INDUS
# INDUS_CHAS
# INDUS_NOX
# INDUS_RM
# INDUS_AGE
# INDUS_DIS
# INDUS_RAD
# INDUS_TAX
# INDUS_PTRATIO
# INDUS_B
# INDUS_LSTAT
# CHAS_CHAS
# CHAS_NOX
# CHAS_RM
# CHAS_AGE
# CHAS_DIS
# CHAS_RAD
# CHAS_TAX
# CHAS_PTRATIO
# CHAS_B
# CHAS_LSTAT
# NOX_NOX
# NOX_RM
# NOX_AGE
# NOX_DIS
# NOX_RAD
# NOX_TAX
# NOX_PTRATIO
# NOX_B
# NOX_LSTAT
# RM_RM
# RM_AGE
# RM_DIS
# RM_RAD
# RM_TAX
# RM_PTRATIO
# RM_B
# RM_LSTAT
# AGE_AGE
# AGE_DIS
# AGE_RAD
# AGE_TAX
# AGE_PTRATIO
# AGE_B
# AGE_LSTAT
# DIS_DIS
# DIS_RAD
# DIS_TAX
# DIS_PTRATIO
# DIS_B
# DIS_LSTAT
# RAD_RAD
# RAD_TAX
# RAD_PTRATIO
# RAD_B
# RAD_LSTAT
# TAX_TAX
# TAX_PTRATIO
# TAX_B
# TAX_LSTAT
# PTRATIO_PTRATIO
# PTRATIO_B
# PTRATIO_LSTAT
# B_B
# B_LSTAT
# LSTAT_LSTAT
# ...

# %%
X=df.values

# %%
X_train, X_test, Y_train,Y_test = ms.train_test_split(X,Y)

# %%
#now we are going to predict the score of this thing

alg1=LR()

alg1.fit(X_train,Y_train)
ypred = alg1.predict(X_test)

print alg1.score(X_train,Y_train)
print alg1.score(X_test,Y_test)
# Out:
# 0.9445386665
# 0.69176998432
