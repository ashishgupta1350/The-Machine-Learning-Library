# %%
from sklearn import datasets as ds
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression as LOR
from sklearn.ensemble import RandomForestClassifier as RFC

from sklearn import model_selection as ms

# %%
data=pd.read_csv('titanic_train.csv')
data.describe()
data.columns=['a','b','c','d','e','f','g','h','survived']
temp=data.b
for i in range(len(temp)):
    if(temp[i]=='male'):
        temp[i]=1
    else:
        temp[i]=0
print 'hello'

# %%
data
temp=data.h
for i in range(len(temp)):
    if(temp[i]=='S'):
        temp[i]=0
    elif temp[i]=='C':
        temp[i]=1
    else: 
        temp[i]=2
print 'hello'

# %%
data
#delete data['f'] for now to avoid editing tickets
# Out:
#      a  b          c  d  e         g  h  survived
# 0    3  1  29.701869  0  0    8.0500  0         0
# 1    2  1  39.000000  0  0   26.0000  0         0
# 2    3  0  29.000000  0  4   21.0750  0         0
# 3    3  1  25.000000  0  0    7.0500  0         0
# 4    3  1  34.500000  0  0    6.4375  1         0
# 5    1  0  35.000000  1  0   53.1000  0         1
# 6    3  1  23.000000  0  0    7.8958  0         0
# 7    2  1  29.701869  0  0   13.0000  0         1
# 8    3  1  50.000000  0  0    8.0500  0         0
# 9    3  0  23.000000  0  0    7.5500  0         1
# 10   3  1  29.701869  0  0    7.2292  1         0
# 11   2  1  36.000000  0  0   13.0000  0         0
# 12   3  1  29.701869  1  0   15.5000  2         0
# 13   3  0  29.701869  0  0    7.7500  2         1
# 14   3  1  28.000000  2  0    7.9250  0         0
# 15   3  1  32.000000  0  0    7.8542  0         1
# 16   3  1  42.000000  0  0    7.5500  0         0
# 17   1  1  38.000000  0  1  153.4625  0         0
# 18   3  0  29.701869  0  0    7.7500  2         1
# 19   1  1  38.000000  0  0    0.0000  0         0
# 20   3  0  29.701869  0  2   15.2458  1         0
# 21   2  0  40.000000  0  0   15.7500  0         1
# 22   3  1  24.500000  0  0    8.0500  0         0
# 23   3  0  29.701869  0  0    7.2250  1         1
# 24   3  0  29.701869  8  2   69.5500  0         0
# 25   1  1  39.000000  0  0    0.0000  0         0
# 26   1  1  22.000000  0  0  135.6333  1         0
# 27   3  1  16.000000  0  0    7.7750  0         0
# 28   2  1  30.000000  0  0   13.0000  0         0
# 29   1  0  39.000000  1  1   79.6500  0         1
# ..  .. ..        ... .. ..       ... ..       ...
# 637  3  1  24.000000  2  0   24.1500  0         0
# 638  2  0  22.000000  1  2   41.5792  1         1
# 639  3  0  29.701869  3  1   25.4667  0         0
# 640  3  1  32.000000  0  0    7.9250  0         1
# 641  1  1  42.000000  0  0   26.2875  0         1
# 642  3  1  17.000000  0  0    7.1250  0         0
# 643  1  1  29.701869  0  0   25.9250  0         0
# 644  2  1   0.830000  1  1   18.7500  0         1
# 645  3  0   9.000000  2  2   34.3750  0         0
# 646  1  1  58.000000  0  0   29.7000  1         0
# 647  2  1  28.000000  0  1   33.0000  0         0
# 648  3  1  26.000000  0  0    8.0500  0         0
# 649  3  1  47.000000  0  0    9.0000  0         0
# 650  3  1  29.701869  1  0   16.1000  0         0
# 651  2  0  33.000000  1  2   27.7500  0         1
# 652  3  0  47.000000  1  0   14.5000  0         0
# 653  3  1  29.701869  0  0    7.8958  0         0
# 654  1  1  42.000000  1  0   52.5542  0         1
# 655  3  1  36.000000  0  0    7.8958  0         0
# 656  3  1  38.000000  0  0    8.6625  0         0
# 657  3  0  38.000000  1  5   31.3875  0         1
# 658  3  1  29.701869  0  0    7.8292  2         0
# 659  2  1   1.000000  2  1   39.0000  0         1
# 660  1  0  29.701869  1  0   82.1708  1         1
# 661  1  1  47.000000  0  0   34.0208  0         0
# 662  2  0  17.000000  0  0   10.5000  0         1
# 663  3  1  29.701869  0  0    7.7500  2         0
# 664  3  1  32.000000  0  0   56.4958  0         1
# 665  3  0  22.000000  0  0    9.8375  0         0
# 666  3  0  29.701869  1  0   15.5000  2         1
#
# [667 rows x 8 columns]

# %%
N=len(data.a)
mean_=(data.c).mean()
a=data.c
arr= data.c.isnull() 
nan=a[0]
for i in range(N):
    if arr[i]:
        a[i]=mean_
# Out:
#      a  b          c  d  e         g  h  survived  a_a a_b        ...         \
# 0    3  1  29.701869  0  0    8.0500  0         0    9   3        ...
# 1    2  1  39.000000  0  0   26.0000  0         0    4   2        ...
# 2    3  0  29.000000  0  4   21.0750  0         0    9   0        ...
# 3    3  1  25.000000  0  0    7.0500  0         0    9   3        ...
# 4    3  1  34.500000  0  0    6.4375  1         0    9   3        ...
# 5    1  0  35.000000  1  0   53.1000  0         1    1   0        ...
# 6    3  1  23.000000  0  0    7.8958  0         0    9   3        ...
# 7    2  1  29.701869  0  0   13.0000  0         1    4   2        ...
# 8    3  1  50.000000  0  0    8.0500  0         0    9   3        ...
# 9    3  0  23.000000  0  0    7.5500  0         1    9   0        ...
# 10   3  1  29.701869  0  0    7.2292  1         0    9   3        ...
# 11   2  1  36.000000  0  0   13.0000  0         0    4   2        ...
# 12   3  1  29.701869  1  0   15.5000  2         0    9   3        ...
# 13   3  0  29.701869  0  0    7.7500  2         1    9   0        ...
# 14   3  1  28.000000  2  0    7.9250  0         0    9   3        ...
# 15   3  1  32.000000  0  0    7.8542  0         1    9   3        ...
# 16   3  1  42.000000  0  0    7.5500  0         0    9   3        ...
# 17   1  1  38.000000  0  1  153.4625  0         0    1   1        ...
# 18   3  0  29.701869  0  0    7.7500  2         1    9   0        ...
# 19   1  1  38.000000  0  0    0.0000  0         0    1   1        ...
# 20   3  0  29.701869  0  2   15.2458  1         0    9   0        ...
# 21   2  0  40.000000  0  0   15.7500  0         1    4   0        ...
# 22   3  1  24.500000  0  0    8.0500  0         0    9   3        ...
# 23   3  0  29.701869  0  0    7.2250  1         1    9   0        ...
# 24   3  0  29.701869  8  2   69.5500  0         0    9   0        ...
# 25   1  1  39.000000  0  0    0.0000  0         0    1   1        ...
# 26   1  1  22.000000  0  0  135.6333  1         0    1   1        ...
# 27   3  1  16.000000  0  0    7.7750  0         0    9   3        ...
# 28   2  1  30.000000  0  0   13.0000  0         0    4   2        ...
# 29   1  0  39.000000  1  1   79.6500  0         1    1   0        ...
# ..  .. ..        ... .. ..       ... ..       ...  ...  ..        ...
# 637  3  1  24.000000  2  0   24.1500  0         0    9   3        ...
# 638  2  0  22.000000  1  2   41.5792  1         1    4   0        ...
# 639  3  0  29.701869  3  1   25.4667  0         0    9   0        ...
# 640  3  1  32.000000  0  0    7.9250  0         1    9   3        ...
# 641  1  1  42.000000  0  0   26.2875  0         1    1   1        ...
# 642  3  1  17.000000  0  0    7.1250  0         0    9   3        ...
        str1=data.columns[i]
        str2=data.columns[j]
        strnew=str1+'_'+str2
        data[strnew]=data[str1]*data[str2]

data.describe()
# Out:
#                 a           c           d           e           g    survived  \
# count  667.000000  667.000000  667.000000  667.000000  667.000000  667.000000
# mean     2.296852   29.701869    0.527736    0.407796   32.073644    0.401799
# std      0.832182   12.763113    1.080983    0.855190   45.354237    0.490630
# min      1.000000    0.670000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   23.000000    0.000000    0.000000    7.925000    0.000000
# 50%      3.000000   29.701869    0.000000    0.000000   14.500000    0.000000
# 75%      3.000000   35.000000    1.000000    0.000000   31.275000    1.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200    1.000000
#
#               a_a         a_c         a_d         a_e  \
# count  667.000000  667.000000  667.000000  667.000000
# mean     5.967016   65.179109    1.281859    0.965517
# std      3.431718   33.888321    3.117087    2.287256
# min      1.000000    0.920000    0.000000    0.000000
# 25%      4.000000   39.000000    0.000000    0.000000
# 50%      9.000000   63.000000    0.000000    0.000000
# 75%      9.000000   89.105607    1.000000    0.000000
# max      9.000000  222.000000   24.000000   18.000000
#
#                       ...                   e_survived_e_survived  \
# count                 ...                              667.000000
# mean                  ...                                0.343328
# std                   ...                                1.423936
# min                   ...                                0.000000
# 25%                   ...                                0.000000
# 50%                   ...                                0.000000
# 75%                   ...                                0.000000
# max                   ...                               25.000000
#
#        e_survived_g_g  e_survived_g_survived  e_survived_survived_survived  \
# count      667.000000             667.000000                    667.000000
# mean      1137.202928               9.884339                      0.190405
# std       8757.494992              43.642135                      0.554559
# min          0.000000               0.000000                      0.000000
# 25%          0.000000               0.000000                      0.000000
# 50%          0.000000               0.000000                      0.000000
# 75%          0.000000               0.000000                      0.000000
# max     138338.000000             526.000000                      5.000000
#
#             g_g_g_g  g_g_g_survived  g_g_survived_survived  \
# count  6.670000e+02    6.670000e+02             667.000000
# mean   1.807850e+08    4.615263e+05            2119.484825
# std    2.704236e+09    5.401736e+06           12137.997256
# min    0.000000e+00    0.000000e+00               0.000000
# 25%    3.944547e+03    0.000000e+00               0.000000
# 50%    4.420506e+04    0.000000e+00               0.000000
# 75%    9.567297e+05    4.173281e+03             259.210000
# max    6.889639e+10    1.344768e+08          262481.209173
#
#        g_survived_g_survived  g_survived_survived_survived  \
# count             667.000000                    667.000000
# mean             2119.484825                     18.336945
# std             12137.997256                     42.260133
# min                 0.000000                      0.000000
# 25%                 0.000000                      0.000000
# 50%                 0.000000                      0.000000
# 75%               259.210000                     16.100000
# max            262481.209173                    512.329200
#
#        survived_survived_survived_survived
# count                           667.000000
# mean                              0.401799
# std                               0.490630
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               1.000000
# max                               1.000000
#
# [8 rows x 384 columns]

# %%
npdata=data.values

X=npdata[:,0:26]
Y=npdata[:,26]
clf=RFC(n_estimators=1000)
X=X.astype('float')
Y=Y.astype('int')
clf.fit(X,Y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-bc2813cda983> in <module>()
#       6 X=X.astype('float')
#       7 Y=Y.astype('int')
# ----> 8 clf.fit(X,Y)
#
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\sklearn\ensemble\forest.pyc in fit(self, X, y, sample_weight)
#     326                     t, self, X, y, sample_weight, i, len(trees),
#     327                     verbose=self.verbose, class_weight=self.class_weight)
# --> 328                 for i, t in enumerate(trees))
#     329
#     330             # Collect newly grown trees
#
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\sklearn\externals\joblib\parallel.pyc in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\sklearn\externals\joblib\parallel.pyc in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\sklearn\externals\joblib\_parallel_backends.pyc in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\sklearn\externals\joblib\_parallel_backends.pyc in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\sklearn\ensemble\forest.pyc in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     119             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     120
# --> 121         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     122     else:
#     123         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\sklearn\tree\tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\sklearn\tree\tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     360                                            min_impurity_split)
#     361
# --> 362         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     363
#     364         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
data_test=pd.read_csv('titanic_test.csv')
data_test.describe()
data_test.columns=['a','b','c','d','e','f','g']
'''for i in range(len(data.b)):
    if(data.b[i]=='male'):
        data.b[i]=1
    else:
        data.b[i]=0'''

a=data_test.b
for i in range(len(a)):
    if(a[i]=='male'):
        a[i]=1
    else: 
        a[i]=0

N=len(data_test.c)
mean_=(data_test.c).mean()
a=data_test.c
arr= data_test.c.isnull() 
for i in range(N):
    if arr[i]:
        a[i]=mean_
        
data_test
# Out:
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      a  b          c  d  e         f    g
# 0    1  0  49.000000  0  0   25.9292    S
# 1    3  1  29.817345  0  0    7.7375    Q
# 2    2  0  24.000000  2  1   27.0000    S
# 3    1  1  36.000000  0  0   26.2875    S
# 4    1  1  71.000000  0  0   49.5042    C
# 5    3  1  16.000000  0  0    9.5000    S
# 6    3  1  29.817345  0  0    7.7250    Q
# 7    3  0  18.000000  0  0    7.7750    S
# 8    3  1  29.817345  0  0    8.6625    S
# 9    1  0  63.000000  1  0   77.9583    S
# 10   3  1  29.817345  0  0    7.8958    S
# 11   1  0  24.000000  0  0   83.1583    C
# 12   3  0  23.000000  0  0    7.9250    S
# 13   1  1  71.000000  0  0   34.6542    C
# 14   2  1  21.000000  1  0   11.5000    S
# 15   3  1  21.000000  0  0    8.4333    S
# 16   3  1   4.000000  1  1   11.1333    S
# 17   3  1  22.000000  0  0    7.5208    S
# 18   3  0  18.000000  0  0    6.7500    Q
# 19   3  0  29.817345  1  0   24.1500    Q
# 20   3  1  32.000000  0  0    7.7500    Q
# 21   1  0  58.000000  0  0   26.5500    S
# 22   2  0  24.000000  1  2   65.0000    S
# 23   3  1  29.817345  0  0    7.2500    S
# 24   1  1  29.817345  0  0   35.0000    S
# 25   2  1  28.000000  0  0   10.5000    S
# 26   1  1  42.000000  1  0   52.0000    S
# 27   3  0   0.750000  2  1   19.2583    C
# 28   2  0  50.000000  0  0   10.5000    S
# 29   2  1  23.000000  0  0   13.0000    S
# ..  .. ..        ... .. ..       ...  ...
# 192  3  1  29.817345  0  0    8.0500    S
# 193  3  1  38.000000  0  0    7.8958    S
# 194  3  0  26.000000  0  0    7.9250    S
# 195  1  0  16.000000  0  1   57.9792    C
# 196  3  0  37.000000  0  0    9.5875    S
# 197  2  0  28.000000  1  0   26.0000    S
# 198  1  0  33.000000  0  0   86.5000    S
# 199  3  1  29.817345  0  0    7.7500    Q
# 200  1  1  32.000000  0  0   30.5000    C
# 201  3  1  22.000000  0  0    7.2500    S
# 202  1  1  47.000000  0  0   38.5000    S
# 203  3  1  29.817345  0  0    7.7500    Q
# 204  3  1  29.817345  1  0   19.9667    S
# 205  3  1  32.000000  0  0   56.4958    S
# 206  3  1  26.000000  0  0    7.8958    S
# 207  1  0  62.000000  0  0   80.0000  NaN
# 208  3  0   9.000000  3  2   27.9000    S
# 209  3  1  29.817345  2  0   21.6792    C
# 210  3  0  22.000000  0  0    7.7750    S
# 211  2  1  25.000000  0  0   13.0000    S
# 212  1  1  55.000000  0  0   30.5000    S
# 213  3  0  14.000000  0  0    7.8542    S
# 214  2  0  29.817345  0  0   12.3500    Q
# 215  3  1  21.000000  0  0    8.6625    S
# 216  3  1  29.817345  0  0    8.0500    S
# 217  3  1  20.000000  1  0    7.9250    S
# 218  1  1  45.000000  0  0   26.5500    S
# 219  1  0  17.000000  1  0  108.9000    C
# 220  3  1  43.000000  0  0    6.4500    S
# 221  2  1  36.500000  0  2   26.0000    S
#
# [222 rows x 7 columns]

# %%
a=data_test.g
for i in range(len(a)):
    if(a[i]=='S'):
        a[i]=0
    elif a[i]=='C':
        a[i]=1
    else: 
        a[i]=2
# Out:
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data_test=data_test.astype('float')
data_test
# Out:
#        a    b          c    d    e         f    g
# 0    1.0  0.0  49.000000  0.0  0.0   25.9292  0.0
# 1    3.0  1.0  29.817345  0.0  0.0    7.7375  2.0
# 2    2.0  0.0  24.000000  2.0  1.0   27.0000  0.0
# 3    1.0  1.0  36.000000  0.0  0.0   26.2875  0.0
# 4    1.0  1.0  71.000000  0.0  0.0   49.5042  1.0
# 5    3.0  1.0  16.000000  0.0  0.0    9.5000  0.0
# 6    3.0  1.0  29.817345  0.0  0.0    7.7250  2.0
# 7    3.0  0.0  18.000000  0.0  0.0    7.7750  0.0
# 8    3.0  1.0  29.817345  0.0  0.0    8.6625  0.0
# 9    1.0  0.0  63.000000  1.0  0.0   77.9583  0.0
# 10   3.0  1.0  29.817345  0.0  0.0    7.8958  0.0
# 11   1.0  0.0  24.000000  0.0  0.0   83.1583  1.0
# 12   3.0  0.0  23.000000  0.0  0.0    7.9250  0.0
# 13   1.0  1.0  71.000000  0.0  0.0   34.6542  1.0
# 14   2.0  1.0  21.000000  1.0  0.0   11.5000  0.0
# 15   3.0  1.0  21.000000  0.0  0.0    8.4333  0.0
# 16   3.0  1.0   4.000000  1.0  1.0   11.1333  0.0
# 17   3.0  1.0  22.000000  0.0  0.0    7.5208  0.0
# 18   3.0  0.0  18.000000  0.0  0.0    6.7500  2.0
# 19   3.0  0.0  29.817345  1.0  0.0   24.1500  2.0
# 20   3.0  1.0  32.000000  0.0  0.0    7.7500  2.0
# 21   1.0  0.0  58.000000  0.0  0.0   26.5500  0.0
# 22   2.0  0.0  24.000000  1.0  2.0   65.0000  0.0
# 23   3.0  1.0  29.817345  0.0  0.0    7.2500  0.0
# 24   1.0  1.0  29.817345  0.0  0.0   35.0000  0.0
# 25   2.0  1.0  28.000000  0.0  0.0   10.5000  0.0
# 26   1.0  1.0  42.000000  1.0  0.0   52.0000  0.0
# 27   3.0  0.0   0.750000  2.0  1.0   19.2583  1.0
# 28   2.0  0.0  50.000000  0.0  0.0   10.5000  0.0
# 29   2.0  1.0  23.000000  0.0  0.0   13.0000  0.0
# ..   ...  ...        ...  ...  ...       ...  ...
# 192  3.0  1.0  29.817345  0.0  0.0    8.0500  0.0
# 193  3.0  1.0  38.000000  0.0  0.0    7.8958  0.0
# 194  3.0  0.0  26.000000  0.0  0.0    7.9250  0.0
# 195  1.0  0.0  16.000000  0.0  1.0   57.9792  1.0
# 196  3.0  0.0  37.000000  0.0  0.0    9.5875  0.0
# 197  2.0  0.0  28.000000  1.0  0.0   26.0000  0.0
# 198  1.0  0.0  33.000000  0.0  0.0   86.5000  0.0
# 199  3.0  1.0  29.817345  0.0  0.0    7.7500  2.0
# 200  1.0  1.0  32.000000  0.0  0.0   30.5000  1.0
# 201  3.0  1.0  22.000000  0.0  0.0    7.2500  0.0
# 202  1.0  1.0  47.000000  0.0  0.0   38.5000  0.0
# 203  3.0  1.0  29.817345  0.0  0.0    7.7500  2.0
# 204  3.0  1.0  29.817345  1.0  0.0   19.9667  0.0
# 205  3.0  1.0  32.000000  0.0  0.0   56.4958  0.0
# 206  3.0  1.0  26.000000  0.0  0.0    7.8958  0.0
# 207  1.0  0.0  62.000000  0.0  0.0   80.0000  2.0
# 208  3.0  0.0   9.000000  3.0  2.0   27.9000  0.0
# 209  3.0  1.0  29.817345  2.0  0.0   21.6792  1.0
# 210  3.0  0.0  22.000000  0.0  0.0    7.7750  0.0
# 211  2.0  1.0  25.000000  0.0  0.0   13.0000  0.0
# 212  1.0  1.0  55.000000  0.0  0.0   30.5000  0.0
# 213  3.0  0.0  14.000000  0.0  0.0    7.8542  0.0
# 214  2.0  0.0  29.817345  0.0  0.0   12.3500  2.0
# 215  3.0  1.0  21.000000  0.0  0.0    8.6625  0.0
# 216  3.0  1.0  29.817345  0.0  0.0    8.0500  0.0
# 217  3.0  1.0  20.000000  1.0  0.0    7.9250  0.0
# 218  1.0  1.0  45.000000  0.0  0.0   26.5500  0.0
# 219  1.0  0.0  17.000000  1.0  0.0  108.9000  1.0
# 220  3.0  1.0  43.000000  0.0  0.0    6.4500  0.0
# 221  2.0  1.0  36.500000  0.0  2.0   26.0000  0.0
#
# [222 rows x 7 columns]

# %%
ypred=clf.predict(data_test)

# %%
np.savetxt('pred_values_titanic.csv',ypred,fmt='%.0f')
