# %%
import numpy as np
import pandas as pd

# %%
data=np.loadtxt('data.csv',delimiter=',')

# %%
# m is clearly a matrix of (n+1)*1 order because we add another 
#feature x[i]=1 in data[m*n+1]

def cost(data,Y,m):
    Cost=0
    M=len(data)
    Cost=(1/M)*sum((data.dot(m)-Y.reshape(379,1))**2)
    return Cost

# %%
def step_gradient(data,Y,lRate,m):
    M=len(data)
    N=data.shape[1]
    sum_=np.zeros((N,1)) 
    m=m-(-2/M)*lRate*(data.T).dot(Y.reshape(379,1)-data.dot(m))   
    #print m.shape
    return m

def gradient_descent(data,Y,lRate,numIter):
    #there is no c here
    N=data.shape[1]
    m=np.zeros((N,1))
    
    for i in range(numIter):        
        m=step_gradient(data,Y,lRate,m) 
    return m

# %%
def run():
    data=np.loadtxt('boston_data.csv',delimiter=',')
    X=data[:,0:13]
    Y=data[:,13]
    myData=np.c_[np.ones(len(X)),X ] 
    
    data_test=np.loadtxt('boston_test.csv',delimiter=',')
    data_test=np.c_[np.ones(len(data_test)),data_test ] 
    
    #normalize all the features code
    for i in range(1,X.shape[1]):
        mu=myData[:,i].mean()
        sigma=myData[:,i].std()
        myData[:,i]=(myData[:,i]-mu)/sigma
    #end of normalization
    
    #normalize all the features code
    for i in range(1,data_test.shape[1]):
        mu=data_test[:,i].mean()
        sigma=data_test[:,i].std()
        data_test[:,i]=(data_test[:,i]-mu)/sigma
    #end of normalization
    
    #adding some extra features
    for i in range(X.shape[1]):
        for j in range(i,X.shape[1]):
            col=myData[:,i]*myData[:,j]
            col_test=data_test[:,i]*data_test[:,j]

            #print myData.shape,col.shape
            myData=np.append(myData,col.reshape(379,1),axis=1)
            data_test=np.append(data_test,col_test.reshape(127,1),axis=1)
    
    #normalize all the features code
    for i in range(1,X.shape[1]):
        mu=myData[:,i].mean()
        sigma=myData[:,i].std()
        myData[:,i]=(myData[:,i]-mu)/sigma
    #end of normalization
     
    
    #normalize all the features code
    for i in range(1,data_test.shape[1]):
        mu=data_test[:,i].mean()
        sigma=data_test[:,i].std()
        data_test[:,i]=(data_test[:,i]-mu)/sigma
    #end of normalization
    
    print myData.shape
    print data_test.shape
    #end of extra features
    
    learningRate=0.00001
    numIterations=1000000
    m=gradient_descent(myData,Y,learningRate,numIterations)
    print m
    
    ypred=data_test.dot(m)
    np.savetxt('predictedValues.csv',ypred,fmt='%.5f')

# %%
run()
# Out:
# C:\Users\80LM0141IH\Anaconda3\envs\py27\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in divide
# (379L, 105L)
# (127L, 105L)
# [[  9.33689218]
#  [ -0.98138498]
#  [ -0.58601115]
#  [  1.97409483]
#  [ -2.26254634]
#  [ -1.39176385]
#  [  1.32056449]
#  [ -1.07867624]
#  [ -1.53801903]
#  [ -1.0329654 ]
#  [  1.84302803]
#  [ -1.42214323]
#  [ -0.03795081]
#  [ -3.60058241]
#  [  9.33689218]
#  [ -0.98138498]
#  [ -0.58601115]
#  [  1.97409483]
#  [ -2.26254634]
#  [ -1.39176385]
#  [  1.32056449]
#  [ -1.07867624]
#  [ -1.53801903]
#  [ -1.0329654 ]
#  [  1.84302803]
#  [ -1.42214323]
#  [ -0.03795081]
#  [  0.38239693]
#  [  1.97030538]
#  [  7.99797509]
#  [  6.07515561]
#  [  0.22018354]
#  [ -0.42371983]
#  [ -1.59749416]
#  [ -2.03662998]
#  [ -3.39020363]
#  [ -1.04515075]
#  [ -2.0951639 ]
#  [ -0.28686536]
#  [ -0.30146342]
#  [ -1.84401458]
#  [ -0.01335675]
#  [ -3.10268696]
#  [  0.02885015]
#  [ -0.59649717]
#  [ -1.5324331 ]
#  [ -0.72505347]
#  [  3.52170108]
#  [ -0.44639341]
#  [ -0.27462626]
#  [  1.5936724 ]
#  [  0.20999333]
#  [  1.01880596]
#  [  1.54839165]
#  [  0.84033626]
#  [  1.93912265]
#  [ -1.42023468]
#  [  0.73034704]
#  [  0.11058591]
#  [  1.27638803]
#  [  2.127984  ]
#  [ -1.99873571]
#  [ -0.7833762 ]
#  [ -0.39258277]
#  [ -0.96141313]
#  [ -0.16478461]
#  [  0.93615801]
#  [ -0.48886381]
#  [  0.66710267]
#  [ -0.14830251]
#  [ -0.42492879]
#  [ -1.83785809]
#  [  5.81415396]
#  [ -2.84298989]
#  [  5.69416763]
#  [ -4.50218988]
#  [ -0.82540899]
#  [  0.61957502]
#  [ -0.60895401]
#  [ -0.06078758]
#  [  0.01545024]
#  [ -1.56110718]
#  [ -1.14941534]
#  [  0.05496293]
#  [  0.57252137]
#  [  0.7919335 ]
#  [  4.0015028 ]
#  [ -3.62518608]
#  [  0.15369517]
#  [ -1.40156163]
#  [  3.35061263]
#  [ -2.372969  ]
#  [ -1.25596148]
#  [ -1.6903681 ]
#  [ -0.71796214]
#  [ -9.37135223]
#  [ 11.09209102]
#  [ -2.23511099]
#  [ -0.40608894]
#  [ -2.71107773]
#  [  2.69219309]
#  [  0.97700949]
#  [  0.15525654]
#  [ -0.93095073]
#  [ -0.32741865]]
